# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## In this notebook, I'm going to repeat the steps I took in the previous notebook, this time looking at 2016 data.

# %%
df = pd.read_csv('./data/guns2_clean.csv', index_col = 0)

# %%
df.head()
# Out:
#                      state        city  \
# date
# 2013-01-01    Pennsylvania  Mckeesport
# 2013-01-01      California   Hawthorne
# 2013-01-01            Ohio      Lorain
# 2013-01-05        Colorado      Aurora
# 2013-01-07  North Carolina  Greensboro
#
#                                               address  n_killed  n_injured  \
# date
# 2013-01-01  1506 Versailles Avenue and Coursin Street         0          4
# 2013-01-01               13500 block of Cerise Avenue         1          3
# 2013-01-01                      1776 East 28th Street         1          3
# 2013-01-05           16000 block of East Ithaca Place         4          0
# 2013-01-07                  307 Mourning Dove Terrace         2          2
#
#                                                  incident_url  \
# date
# 2013-01-01  http://www.gunviolencearchive.org/incident/461105
# 2013-01-01  http://www.gunviolencearchive.org/incident/460726
# 2013-01-01  http://www.gunviolencearchive.org/incident/478855
# 2013-01-05  http://www.gunviolencearchive.org/incident/478925
# 2013-01-07  http://www.gunviolencearchive.org/incident/478959
#
#                                                    source_url  \
# date
# 2013-01-01  http://www.post-gazette.com/local/south/2013/0...
# 2013-01-01  http://www.dailybulletin.com/article/zz/201301...
# 2013-01-01  http://chronicle.northcoastnow.com/2013/02/14/...
# 2013-01-05  http://www.dailydemocrat.com/20130106/aurora-s...
# 2013-01-07  http://www.journalnow.com/news/local/article_d...
#
#             incident_url_fields_missing  congressional_district  \
# date
# 2013-01-01                          0.0                    14.0
# 2013-01-01                          0.0                    43.0
# 2013-01-01                          0.0                     9.0
# 2013-01-05                          0.0                     6.0
# 2013-01-07                          0.0                     6.0
#
#                         gun_stolen          ...           \
# date                                        ...
# 2013-01-01                     NaN          ...
# 2013-01-01                     NaN          ...
# 2013-01-01  0::Unknown||1::Unknown          ...
# 2013-01-05                     NaN          ...
# 2013-01-07  0::Unknown||1::Unknown          ...
#
#                               participant_age  \
# date
# 2013-01-01                              0::20
# 2013-01-01                              0::20
# 2013-01-01  0::25||1::31||2::33||3::34||4::33
# 2013-01-05         0::29||1::33||2::56||3::33
# 2013-01-07         0::18||1::46||2::14||3::47
#
#                                         participant_age_group  \
# date
# 2013-01-01  0::Adult 18+||1::Adult 18+||2::Adult 18+||3::A...
# 2013-01-01  0::Adult 18+||1::Adult 18+||2::Adult 18+||3::A...
# 2013-01-01  0::Adult 18+||1::Adult 18+||2::Adult 18+||3::A...
# 2013-01-05  0::Adult 18+||1::Adult 18+||2::Adult 18+||3::A...
# 2013-01-07  0::Adult 18+||1::Adult 18+||2::Teen 12-17||3::...
#
#                                      participant_gender  \
# date
# 2013-01-01         0::Male||1::Male||3::Male||4::Female
# 2013-01-01                                      0::Male
# 2013-01-01  0::Male||1::Male||2::Male||3::Male||4::Male
# 2013-01-05         0::Female||1::Male||2::Male||3::Male
# 2013-01-07       0::Female||1::Male||2::Male||3::Female
#
#                                              participant_name  \
# date
# 2013-01-01                                     0::Julian Sims
# 2013-01-01                                  0::Bernard Gillis
# 2013-01-01  0::Damien Bell||1::Desmen Noble||2::Herman Sea...
# 2013-01-05  0::Stacie Philbrook||1::Christopher Ratliffe||...
# 2013-01-07  0::Danielle Imani Jameison||1::Maurice Eugene ...
#
#             participant_relationship  \
# date
# 2013-01-01                       NaN
# 2013-01-01                       NaN
# 2013-01-01                       NaN
# 2013-01-05                       NaN
# 2013-01-07                 3::Family
#
#                                            participant_status  \
# date
# 2013-01-01  0::Arrested||1::Injured||2::Injured||3::Injure...
# 2013-01-01      0::Killed||1::Injured||2::Injured||3::Injured
# 2013-01-01  0::Injured, Unharmed, Arrested||1::Unharmed, A...
# 2013-01-05         0::Killed||1::Killed||2::Killed||3::Killed
# 2013-01-07       0::Injured||1::Injured||2::Killed||3::Killed
#
#                                              participant_type  \
# date
# 2013-01-01  0::Victim||1::Victim||2::Victim||3::Victim||4:...
# 2013-01-01  0::Victim||1::Victim||2::Victim||3::Victim||4:...
# 2013-01-01  0::Subject-Suspect||1::Subject-Suspect||2::Vic...
# 2013-01-05  0::Victim||1::Victim||2::Victim||3::Subject-Su...
# 2013-01-07  0::Victim||1::Victim||2::Victim||3::Subject-Su...
#
#                                                       sources  \
# date
# 2013-01-01  http://pittsburgh.cbslocal.com/2013/01/01/4-pe...
# 2013-01-01  http://losangeles.cbslocal.com/2013/01/01/man-...
# 2013-01-01  http://www.morningjournal.com/general-news/201...
# 2013-01-05  http://denver.cbslocal.com/2013/01/06/officer-...
# 2013-01-07  http://myfox8.com/2013/01/08/update-mother-sho...
#
#            state_house_district state_senate_district
# date
# 2013-01-01                  NaN                   NaN
# 2013-01-01                 62.0                  35.0
# 2013-01-01                 56.0                  13.0
# 2013-01-05                 40.0                  28.0
# 2013-01-07                 62.0                  27.0
#
# [5 rows x 27 columns]

# %%
df_2016 = df.loc['2016-01-01':'2016-12-31']

# %%
pd.options.mode.chained_assignment = None

# %%
df_2016['city'] = df_2016['city'] + ", " + df_2016['state']

# %%
df_2016.drop(['state'], axis=1, inplace=True)

# %%
df_2016.head()
# Out:
#                              city                            address  \
# date
# 2016-01-01  Little Rock, Arkansas                  22nd and Bragg St
# 2016-01-01       Peoria, Illinois            415 W. Sam J. Stone Ave
# 2016-01-01       Peoria, Illinois              6516 N. University St
# 2016-01-01     Tacoma, Washington  1600 block of South Mullen Street
# 2016-01-01     Parker, Washington                      Parker Street
#
#             n_killed  n_injured  \
# date
# 2016-01-01         1          0
# 2016-01-01         0          0
# 2016-01-01         0          1
# 2016-01-01         0          0
# 2016-01-01         0          1
#
#                                                  incident_url  \
# date
# 2016-01-01  http://www.gunviolencearchive.org/incident/476949
# 2016-01-01  http://www.gunviolencearchive.org/incident/477024
# 2016-01-01  http://www.gunviolencearchive.org/incident/477016
# 2016-01-01  http://www.gunviolencearchive.org/incident/484955
# 2016-01-01  http://www.gunviolencearchive.org/incident/478044
#
#                                                    source_url  \
# date
# 2016-01-01  http://www.thv11.com/news/local/suspect-in-fir...
# 2016-01-01  http://www.pjstar.com/news/20160101/bullet-dam...
# 2016-01-01  http://www.pjstar.com/news/20160101/police-int...
# 2016-01-01  http://www.thenewstribune.com/news/local/crime...
# 2016-01-01  http://kimatv.com/news/local/suspect-arrested-...
#
#             incident_url_fields_missing  congressional_district  gun_stolen  \
# date
# 2016-01-01                          0.0                     2.0         NaN
# 2016-01-01                          0.0                    17.0         NaN
# 2016-01-01                          0.0                    18.0  0::Unknown
# 2016-01-01                          0.0                     6.0   0::Stolen
# 2016-01-01                          0.0                     4.0         NaN
#
#                 gun_type          ...          participant_age  \
# date                              ...
# 2016-01-01           NaN          ...             0::32||1::28
# 2016-01-01           NaN          ...                      NaN
# 2016-01-01    0::Unknown          ...                    0::24
# 2016-01-01  0::30-30 Win          ...                    0::56
# 2016-01-01           NaN          ...             0::37||1::23
#
#                  participant_age_group participant_gender  \
# date
# 2016-01-01  0::Adult 18+||1::Adult 18+   0::Male||1::Male
# 2016-01-01                         NaN                NaN
# 2016-01-01                0::Adult 18+            0::Male
# 2016-01-01                0::Adult 18+            0::Male
# 2016-01-01  0::Adult 18+||1::Adult 18+   0::Male||1::Male
#
#                              participant_name  participant_relationship  \
# date
# 2016-01-01  0::Terry Jones||1::Robert Cheeter                       NaN
# 2016-01-01                                NaN                       NaN
# 2016-01-01                                NaN                       NaN
# 2016-01-01                                NaN                       NaN
# 2016-01-01                                NaN                       NaN
#
#                            participant_status               participant_type  \
# date
# 2016-01-01             0::Killed||1::Arrested  0::Victim||1::Subject-Suspect
# 2016-01-01                                NaN                            NaN
# 2016-01-01                         0::Injured                      0::Victim
# 2016-01-01              0::Unharmed, Arrested             0::Subject-Suspect
# 2016-01-01  0::Injured||1::Unharmed, Arrested  0::Victim||1::Subject-Suspect
#
#                                                       sources  \
# date
# 2016-01-01  http://katv.com/news/local/police-investigatin...
# 2016-01-01  http://www.pjstar.com/news/20160101/bullet-dam...
# 2016-01-01  http://www.pjstar.com/news/20160101/police-int...
# 2016-01-01  http://www.thenewstribune.com/news/local/crime...
# 2016-01-01  http://kimatv.com/news/local/suspect-arrested-...
#
#            state_house_district state_senate_district
# date
# 2016-01-01                 36.0                  30.0
# 2016-01-01                 92.0                  46.0
# 2016-01-01                 73.0                  37.0
# 2016-01-01                 27.0                  27.0
# 2016-01-01                 14.0                  14.0
#
# [5 rows x 26 columns]

# %%
cities_2016 = pd.DataFrame(df_2016.groupby(['city']).n_killed.sum().sort_values(ascending=False))

# %%
cities_2016.head()
# Out:
#                             n_killed
# city
# Chicago, Illinois                591
# Houston, Texas                   289
# Baltimore, Maryland              264
# Philadelphia, Pennsylvania       221
# Saint Louis, Missouri            218

# %% [markdown]
# ## Loading in Census Bureau csv:

# %%
pop = pd.read_csv('./data/city_pops.csv', header=1, index_col='Rank')

# %%
pop['Geography.2'].replace('city.+', "", regex=True, inplace=True)

# %%
pop['Geography.1'].replace('^(.+?),', "", regex=True, inplace=True)

# %%
pop = pop[['Geography.2', 'Geography.1', 'Population Estimate (as of July 1) - 2016']]

# %%
pop.rename(columns= {'Geography.2':'city', 'Geography.1':'state', 'Population Estimate (as of July 1) - 2016':'2016_pop' }, inplace=True)

# %%
pop['city'] = pop['city'].str.strip()

# %%
pop['state'] = pop['state'].str.strip()

# %%
pop['city'] = pop['city'] + ", " + pop['state']

# %%
pop.set_index(['city'], inplace=True)

# %%
pop.drop('state', axis= 1, inplace=True)

# %%
pop.head()
# Out:
#                          2016_pop
# city
# New York, New York        8615426
# Los Angeles, California   3981116
# Chicago, Illinois         2720275
# Houston, Texas            2304482
# Phoenix, Arizona          1602042

# %% [markdown]
# ## Merging population and gun death dataframes:

# %%
cities_2016 = pd.merge(pop, cities_2016, left_index=True, right_index=True)

# %%
cities_2016.sort_values('n_killed', ascending=False).head(20)
# Out:
#                                   2016_pop  n_killed
# city
# Chicago, Illinois                  2720275       591
# Houston, Texas                     2304482       289
# Baltimore, Maryland                 616958       264
# Philadelphia, Pennsylvania         1574765       221
# New York, New York                 8615426       210
# Memphis, Tennessee                  653369       188
# New Orleans, Louisiana              393021       174
# San Antonio, Texas                 1487738       169
# Indianapolis, Indiana               857453       161
# Las Vegas, Nevada                   631710       159
# Milwaukee, Wisconsin                597508       135
# Cleveland, Ohio                     387451       133
# Orlando, Florida                    277879       132
# Detroit, Michigan                   675480       131
# Dallas, Texas                      1322140       123
# Kansas City, Missouri               482118       116
# Phoenix, Arizona                   1602042       108
# Washington, District of Columbia    684336       106
# Los Angeles, California            3981116       103
# Jacksonville, Florida               880893        95

# %%
cities_2016['pc_killed'] = (cities_2016.n_killed / cities_2016['2016_pop']) * 100000

# %%
top_cities_2016 = cities_2016.sort_values('pc_killed', ascending=False).head(20)
top_cities_2016
# Out:
#                                   2016_pop  n_killed  pc_killed
# city
# Camden, New Jersey                   74513        42  56.366003
# Gary, Indiana                        76595        37  48.306025
# Orlando, Florida                    277879       132  47.502690
# Flint, Michigan                      96985        46  47.430015
# New Orleans, Louisiana              393021       174  44.272443
# Baltimore, Maryland                 616958       264  42.790595
# Birmingham, Alabama                 211263        87  41.180898
# Jackson, Mississippi                169005        64  37.868702
# Cleveland, Ohio                     387451       133  34.326921
# Wilmington, Delaware                 71244        24  33.687047
# Dayton, Ohio                        140743        45  31.973171
# Fort Myers, Florida                  76741        24  31.274026
# Baton Rouge, Louisiana              227352        71  31.229107
# Bradenton, Florida                   54890        17  30.971033
# Elkhart, Indiana                     52567        16  30.437347
# Memphis, Tennessee                  653369       188  28.773939
# Richmond, Virginia                  225288        63  27.964206
# Kansas City, Kansas                 152159        42  27.602705
# Savannah, Georgia                   146264        40  27.347809
# North Charleston, South Carolina    109732        30  27.339336

# %% [markdown]
# ### Reformatting so my dataframe looks better when plotted:

# %%
top_large_cities_2016 = cities_2016[cities_2016['2016_pop']>=500000].sort_values('pc_killed', ascending=False).head(20)
top_large_cities_2016.reset_index(inplace=True)
top_large_cities_2016['city'], top_large_cities_2016['state'] = top_large_cities_2016.city.str.split(', ', 1).str
top_large_cities_2016.set_index('city', inplace=True)
top_large_cities_2016.to_csv('./large_cities_2016.csv')
top_large_cities_2016
# Out:
#                2016_pop  n_killed  pc_killed                 state
# city
# Baltimore        616958       264  42.790595              Maryland
# Memphis          653369       188  28.773939             Tennessee
# Las Vegas        631710       159  25.169777                Nevada
# Milwaukee        597508       135  22.593840             Wisconsin
# Chicago         2720275       591  21.725745              Illinois
# Detroit          675480       131  19.393616              Michigan
# Indianapolis     857453       161  18.776539               Indiana
# Washington       684336       106  15.489467  District of Columbia
# Philadelphia    1574765       221  14.033840          Pennsylvania
# Houston         2304482       289  12.540779                 Texas
# San Antonio     1487738       169  11.359527                 Texas
# Jacksonville     880893        95  10.784511               Florida
# Columbus         863741        90  10.419790                  Ohio
# Oklahoma City    639163        64  10.013095              Oklahoma
# Albuquerque      557509        53   9.506573            New Mexico
# Dallas          1322140       123   9.303100                 Texas
# Denver           694777        57   8.204071              Colorado
# Charlotte        843484        63   7.469021        North Carolina
# Phoenix         1602042       108   6.741396               Arizona
# Boston           678430        43   6.338163         Massachusetts

# %%
sns.set(style="white")

f, ax = plt.subplots(figsize=(10, 8))
colors = ['crimson' if x=='Baltimore, Maryland' else 'black' for x in top_cities_2016.index]
sns.barplot(x=top_cities_2016.pc_killed, 
            y=top_cities_2016.index,
            data=top_cities_2016, palette=colors)


ax.set_title("US Cities by Per Capita Gun Deaths 2016", fontsize=20)
ax.set_xlabel('Gun Deaths per 100k',fontsize=16)
ax.set_ylabel("")
plt.tick_params(labelsize='large')
       
sns.despine(left=True, bottom=True)
plt.savefig('./images/cities_pc_2016.png')

# %%
sns.set(style="white")

f, ax = plt.subplots(figsize=(10, 8))
colors = ['crimson' if x=='Baltimore' else 'black' for x in top_large_cities_2016.index]
sns.barplot(x=top_large_cities_2016.pc_killed, 
            y=top_large_cities_2016.index,
            data=top_large_cities_2016, palette=colors)

ax.set_title("Large US Cities by Per Capita Gun Deaths 2016", fontsize=20)
ax.set_xlabel('Gun Deaths per 100k',fontsize=16)
ax.set_ylabel("")
plt.tick_params(labelsize='large')

sns.despine(left=True, bottom=True)
plt.savefig('./images/large_cities_2016.png')

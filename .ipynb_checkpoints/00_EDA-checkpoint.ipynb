# %% [markdown]
# # Reading in CSVs/Initial Data Cleaning and EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline

# %% [markdown]
# #### This is the first dataset I'll look at:

# %%
guns = pd.read_csv('guns.csv')

# %%
guns.head()
# Out:
#    incident_id        date           state city_or_county  \
# 0       461105  2013-01-01    Pennsylvania     Mckeesport
# 1       460726  2013-01-01      California      Hawthorne
# 2       478855  2013-01-01            Ohio         Lorain
# 3       478925  2013-01-05        Colorado         Aurora
# 4       478959  2013-01-07  North Carolina     Greensboro
#
#                                      address  n_killed  n_injured  \
# 0  1506 Versailles Avenue and Coursin Street         0          4
# 1               13500 block of Cerise Avenue         1          3
# 2                      1776 East 28th Street         1          3
# 3           16000 block of East Ithaca Place         4          0
# 4                  307 Mourning Dove Terrace         2          2
#
#                                         incident_url  \
# 0  http://www.gunviolencearchive.org/incident/461105
# 1  http://www.gunviolencearchive.org/incident/460726
# 2  http://www.gunviolencearchive.org/incident/478855
# 3  http://www.gunviolencearchive.org/incident/478925
# 4  http://www.gunviolencearchive.org/incident/478959
#
#                                           source_url  \
# 0  http://www.post-gazette.com/local/south/2013/0...
# 1  http://www.dailybulletin.com/article/zz/201301...
# 2  http://chronicle.northcoastnow.com/2013/02/14/...
# 3  http://www.dailydemocrat.com/20130106/aurora-s...
# 4  http://www.journalnow.com/news/local/article_d...
#
#    incident_url_fields_missing          ...           \
# 0                        False          ...
# 1                        False          ...
# 2                        False          ...
# 3                        False          ...
# 4                        False          ...
#
#                      participant_age  \
# 0                              0::20
# 1                              0::20
# 2  0::25||1::31||2::33||3::34||4::33
# 3         0::29||1::33||2::56||3::33
# 4         0::18||1::46||2::14||3::47
#
#                                participant_age_group  \
# 0  0::Adult 18+||1::Adult 18+||2::Adult 18+||3::A...
# 1  0::Adult 18+||1::Adult 18+||2::Adult 18+||3::A...
# 2  0::Adult 18+||1::Adult 18+||2::Adult 18+||3::A...
# 3  0::Adult 18+||1::Adult 18+||2::Adult 18+||3::A...
# 4  0::Adult 18+||1::Adult 18+||2::Teen 12-17||3::...
#
#                             participant_gender  \
# 0         0::Male||1::Male||3::Male||4::Female
# 1                                      0::Male
# 2  0::Male||1::Male||2::Male||3::Male||4::Male
# 3         0::Female||1::Male||2::Male||3::Male
# 4       0::Female||1::Male||2::Male||3::Female
#
#                                     participant_name  \
# 0                                     0::Julian Sims
# 1                                  0::Bernard Gillis
# 2  0::Damien Bell||1::Desmen Noble||2::Herman Sea...
# 3  0::Stacie Philbrook||1::Christopher Ratliffe||...
# 4  0::Danielle Imani Jameison||1::Maurice Eugene ...
#
#    participant_relationship  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                 3::Family
#
#                                   participant_status  \
# 0  0::Arrested||1::Injured||2::Injured||3::Injure...
# 1      0::Killed||1::Injured||2::Injured||3::Injured
# 2  0::Injured, Unharmed, Arrested||1::Unharmed, A...
# 3         0::Killed||1::Killed||2::Killed||3::Killed
# 4       0::Injured||1::Injured||2::Killed||3::Killed
#
#                                     participant_type  \
# 0  0::Victim||1::Victim||2::Victim||3::Victim||4:...
# 1  0::Victim||1::Victim||2::Victim||3::Victim||4:...
# 2  0::Subject-Suspect||1::Subject-Suspect||2::Vic...
# 3  0::Victim||1::Victim||2::Victim||3::Subject-Su...
# 4  0::Victim||1::Victim||2::Victim||3::Subject-Su...
#
#                                              sources state_house_district  \
# 0  http://pittsburgh.cbslocal.com/2013/01/01/4-pe...                  NaN
# 1  http://losangeles.cbslocal.com/2013/01/01/man-...                 62.0
# 2  http://www.morningjournal.com/general-news/201...                 56.0
# 3  http://denver.cbslocal.com/2013/01/06/officer-...                 40.0
# 4  http://myfox8.com/2013/01/08/update-mother-sho...                 62.0
#
#   state_senate_district
# 0                   NaN
# 1                  35.0
# 2                  13.0
# 3                  28.0
# 4                  27.0
#
# [5 rows x 29 columns]

# %%
list(guns.columns)
# Out:
# ['incident_id',
#  'date',
#  'state',
#  'city_or_county',
#  'address',
#  'n_killed',
#  'n_injured',
#  'incident_url',
#  'source_url',
#  'incident_url_fields_missing',
#  'congressional_district',
#  'gun_stolen',
#  'gun_type',
#  'incident_characteristics',
#  'latitude',
#  'location_description',
#  'longitude',
#  'n_guns_involved',
#  'notes',
#  'participant_age',
#  'participant_age_group',
#  'participant_gender',
#  'participant_name',
#  'participant_relationship',
#  'participant_status',
#  'participant_type',
#  'sources',
#  'state_house_district',
#  'state_senate_district']

# %%
guns.drop("incident_id", axis=1, inplace=True)

# %%
guns.date = pd.to_datetime(guns.date)
guns.set_index('date', inplace=True)
guns.sort_index(inplace=True)
guns.head()
# Out:
#                      state city_or_county  \
# date
# 2013-01-01    Pennsylvania     Mckeesport
# 2013-01-01      California      Hawthorne
# 2013-01-01            Ohio         Lorain
# 2013-01-05        Colorado         Aurora
# 2013-01-07  North Carolina     Greensboro
#
#                                               address  n_killed  n_injured  \
# date
# 2013-01-01  1506 Versailles Avenue and Coursin Street         0          4
# 2013-01-01               13500 block of Cerise Avenue         1          3
# 2013-01-01                      1776 East 28th Street         1          3
# 2013-01-05           16000 block of East Ithaca Place         4          0
# 2013-01-07                  307 Mourning Dove Terrace         2          2
#
#                                                  incident_url  \
# date
# 2013-01-01  http://www.gunviolencearchive.org/incident/461105
# 2013-01-01  http://www.gunviolencearchive.org/incident/460726
# 2013-01-01  http://www.gunviolencearchive.org/incident/478855
# 2013-01-05  http://www.gunviolencearchive.org/incident/478925
# 2013-01-07  http://www.gunviolencearchive.org/incident/478959
#
#                                                    source_url  \
# date
# 2013-01-01  http://www.post-gazette.com/local/south/2013/0...
# 2013-01-01  http://www.dailybulletin.com/article/zz/201301...
# 2013-01-01  http://chronicle.northcoastnow.com/2013/02/14/...
# 2013-01-05  http://www.dailydemocrat.com/20130106/aurora-s...
# 2013-01-07  http://www.journalnow.com/news/local/article_d...
#
#             incident_url_fields_missing  congressional_district  \
# date
# 2013-01-01                        False                    14.0
# 2013-01-01                        False                    43.0
# 2013-01-01                        False                     9.0
# 2013-01-05                        False                     6.0
# 2013-01-07                        False                     6.0
#
#                         gun_stolen          ...           \
# date                                        ...
# 2013-01-01                     NaN          ...
# 2013-01-01                     NaN          ...
# 2013-01-01  0::Unknown||1::Unknown          ...
# 2013-01-05                     NaN          ...
# 2013-01-07  0::Unknown||1::Unknown          ...
#
#                               participant_age  \
# date
# 2013-01-01                              0::20
# 2013-01-01                              0::20
# 2013-01-01  0::25||1::31||2::33||3::34||4::33
# 2013-01-05         0::29||1::33||2::56||3::33
# 2013-01-07         0::18||1::46||2::14||3::47
#
#                                         participant_age_group  \
# date
# 2013-01-01  0::Adult 18+||1::Adult 18+||2::Adult 18+||3::A...
# 2013-01-01  0::Adult 18+||1::Adult 18+||2::Adult 18+||3::A...
# 2013-01-01  0::Adult 18+||1::Adult 18+||2::Adult 18+||3::A...
# 2013-01-05  0::Adult 18+||1::Adult 18+||2::Adult 18+||3::A...
# 2013-01-07  0::Adult 18+||1::Adult 18+||2::Teen 12-17||3::...
#
#                                      participant_gender  \
# date
# 2013-01-01         0::Male||1::Male||3::Male||4::Female
# 2013-01-01                                      0::Male
# 2013-01-01  0::Male||1::Male||2::Male||3::Male||4::Male
# 2013-01-05         0::Female||1::Male||2::Male||3::Male
# 2013-01-07       0::Female||1::Male||2::Male||3::Female
#
#                                              participant_name  \
# date
# 2013-01-01                                     0::Julian Sims
# 2013-01-01                                  0::Bernard Gillis
# 2013-01-01  0::Damien Bell||1::Desmen Noble||2::Herman Sea...
# 2013-01-05  0::Stacie Philbrook||1::Christopher Ratliffe||...
# 2013-01-07  0::Danielle Imani Jameison||1::Maurice Eugene ...
#
#             participant_relationship  \
# date
# 2013-01-01                       NaN
# 2013-01-01                       NaN
# 2013-01-01                       NaN
# 2013-01-05                       NaN
# 2013-01-07                 3::Family
#
#                                            participant_status  \
# date
# 2013-01-01  0::Arrested||1::Injured||2::Injured||3::Injure...
# 2013-01-01      0::Killed||1::Injured||2::Injured||3::Injured
# 2013-01-01  0::Injured, Unharmed, Arrested||1::Unharmed, A...
# 2013-01-05         0::Killed||1::Killed||2::Killed||3::Killed
# 2013-01-07       0::Injured||1::Injured||2::Killed||3::Killed
#
#                                              participant_type  \
# date
# 2013-01-01  0::Victim||1::Victim||2::Victim||3::Victim||4:...
# 2013-01-01  0::Victim||1::Victim||2::Victim||3::Victim||4:...
# 2013-01-01  0::Subject-Suspect||1::Subject-Suspect||2::Vic...
# 2013-01-05  0::Victim||1::Victim||2::Victim||3::Subject-Su...
# 2013-01-07  0::Victim||1::Victim||2::Victim||3::Subject-Su...
#
#                                                       sources  \
# date
# 2013-01-01  http://pittsburgh.cbslocal.com/2013/01/01/4-pe...
# 2013-01-01  http://losangeles.cbslocal.com/2013/01/01/man-...
# 2013-01-01  http://www.morningjournal.com/general-news/201...
# 2013-01-05  http://denver.cbslocal.com/2013/01/06/officer-...
# 2013-01-07  http://myfox8.com/2013/01/08/update-mother-sho...
#
#            state_house_district state_senate_district
# date
# 2013-01-01                  NaN                   NaN
# 2013-01-01                 62.0                  35.0
# 2013-01-01                 56.0                  13.0
# 2013-01-05                 40.0                  28.0
# 2013-01-07                 62.0                  27.0
#
# [5 rows x 27 columns]

# %%
years = set(map(lambda x: str(x).split("-")[0], set(guns.index)))

# %%
for year in years:
    print(guns[year].n_killed.sum())
# Out:
# 317
# 12557
# 13484
# 15511
# 3533
# 15066

# %% [markdown]
# #### Looking for the Vegas mass shooting, which doesn't appear to be in my data:

# %%
nevada = guns[guns['state']=='Nevada']

# %%
nevada['10/1/2017':'10/1/2017']
# Out:
#              state city_or_county                                   address  \
# date
# 2017-10-01  Nevada      Las Vegas  E Bonanza Way and N Veterans Memorial Dr
# 2017-10-01  Nevada      Las Vegas                          4855 Boulder Hwy
# 2017-10-01  Nevada      Las Vegas                    U.S. 95 and Craig Road
#
#             n_killed  n_injured  \
# date
# 2017-10-01         1          0
# 2017-10-01         1          0
# 2017-10-01         1          0
#
#                                                  incident_url  \
# date
# 2017-10-01  http://www.gunviolencearchive.org/incident/946298
# 2017-10-01  http://www.gunviolencearchive.org/incident/946448
# 2017-10-01  http://www.gunviolencearchive.org/incident/946494
#
#                                                    source_url  \
# date
# 2017-10-01  https://www.reviewjournal.com/crime/homicides/...
# 2017-10-01  https://www.reviewjournal.com/crime/homicides/...
# 2017-10-01  http://www.ktnv.com/news/man-shot-himself-on-u...
#
#             incident_url_fields_missing  congressional_district  gun_stolen  \
# date
# 2017-10-01                        False                     1.0  0::Unknown
# 2017-10-01                        False                     3.0  0::Unknown
# 2017-10-01                        False                     4.0  0::Unknown
#
#                     ...          participant_age       participant_age_group  \
# date                ...
# 2017-10-01          ...             0::37||1::36  0::Adult 18+||1::Adult 18+
# 2017-10-01          ...                    0::29                0::Adult 18+
# 2017-10-01          ...                      NaN                0::Adult 18+
#
#             participant_gender                             participant_name  \
# date
# 2017-10-01  0::Female||1::Male  0::Daniela Rozada||1::Eduardo Rozado Tomayo
# 2017-10-01             0::Male                   0::Nicholas Joseph Diamond
# 2017-10-01             0::Male                                          NaN
#
#                              participant_relationship      participant_status  \
# date
# 2017-10-01  1::Significant others - current or former  0::Killed||1::Arrested
# 2017-10-01                                        NaN               0::Killed
# 2017-10-01                                        NaN               0::Killed
#
#                          participant_type  \
# date
# 2017-10-01  0::Victim||1::Subject-Suspect
# 2017-10-01                      0::Victim
# 2017-10-01                      0::Victim
#
#                                                       sources  \
# date
# 2017-10-01  https://www.reviewjournal.com/crime/shootings/...
# 2017-10-01  http://www.fox5vegas.com/story/36494229/vegas-...
# 2017-10-01  http://www.ktnv.com/news/man-shot-himself-on-u...
#
#            state_house_district state_senate_district
# date
# 2017-10-01                  6.0                   4.0
# 2017-10-01                 23.0                  12.0
# 2017-10-01                 37.0                   6.0
#
# [3 rows x 27 columns]

# %% [markdown]
# #### It's notably absent from the Kaggle data. This is terrible, because it's a historic data point that's simply too important to ignore. I can either add this event in myself or merge this dataframe with another one that is only comprised of "mass" shootings.

# %% [markdown]
# #### I want to look at the City of Baltimore in particular:

# %%
md = guns[guns.state=='Maryland']

# %%
bmore = guns[guns.city_or_county=='Baltimore']

# %%
print(list(guns.columns))
# Out:
# ['state', 'city_or_county', 'address', 'n_killed', 'n_injured', 'incident_url', 'source_url', 'incident_url_fields_missing', 'congressional_district', 'gun_stolen', 'gun_type', 'incident_characteristics', 'latitude', 'location_description', 'longitude', 'n_guns_involved', 'notes', 'participant_age', 'participant_age_group', 'participant_gender', 'participant_name', 'participant_relationship', 'participant_status', 'participant_type', 'sources', 'state_house_district', 'state_senate_district']

# %%
bmore.n_killed.value_counts()
# Out:
# 0    2937
# 1     961
# 2      41
# 3       4
# Name: n_killed, dtype: int64

# %% [markdown]
# #### For the timeframe contained in my data, there were 1055 gun-related homicides in the City of Baltimore

# %% [markdown]
# ## Looking specifically at mass shootings:

# %%
mass = pd.read_csv('mass_shootings.csv')
print(mass.shape)`
mass.head()
# Out:
# (500, 7)
#         Incident Date                 State City Or County  \
# 0  September 23, 2018            California    Bakersfield
# 1  September 23, 2018            California   Baldwin Park
# 2  September 22, 2018  District of Columbia     Washington
# 3  September 22, 2018              New York      Hempstead
# 4  September 20, 2018              Maryland       Aberdeen
#
#                         Address  # Killed  # Injured  Operations
# 0  2600 block of Chandler Court         1          4         NaN
# 1       3700 block of Loma Lane         0          4         NaN
# 2      1800 block of Benning Rd         0          4         NaN
# 3                      Dolan St         0          4         NaN
# 4              1501 Perryman Rd         4          3         NaN

# %%
mass['Incident Date'] = pd.to_datetime(mass['Incident Date'])

# %%
mass.set_index('Incident Date', inplace=True)
mass.sort_index(inplace=True)
mass.head()
# Out:
#                         State               City Or County  \
# Incident Date
# 2017-04-29         California  Los Angeles (Boyle Heights)
# 2017-04-30         California                    San Diego
# 2017-04-30     South Carolina                        Loris
# 2017-04-30            Florida                 Jacksonville
# 2017-04-30             Kansas                       Topeka
#
#                                       Address  # Killed  # Injured  Operations
# Incident Date
# 2017-04-29     Murchison St and Lancaster Ave         1          3         NaN
# 2017-04-30                   9080 Judicial Dr         2          6         NaN
# 2017-04-30                 268 N Sea Green Rd         1          5         NaN
# 2017-04-30               1200 Ken Knight Dr N         0          5         NaN
# 2017-04-30                       4104 SW 28th         4          1         NaN

# %%
mass.drop('Operations', axis=1, inplace=True)

# %%
mass.shape
# Out:
# (500, 5)

# %%
mass[mass['# Killed']>5]
# Out:
#                      State            City Or County  \
# Incident Date
# 2017-05-27     Mississippi              Bogue Chitto
# 2017-06-05         Florida                   Orlando
# 2017-09-10           Texas                     Plano
# 2017-10-01          Nevada                 Las Vegas
# 2017-11-05           Texas        Sutherland Springs
# 2017-11-14      California                   Corning
# 2018-02-14         Florida  Pompano Beach (Parkland)
# 2018-05-18           Texas                  Santa Fe
# 2018-09-12      California               Bakersfield
#
#                                       Address  # Killed  # Injured
# Incident Date
# 2017-05-27                        2871 Lee Dr         8          1
# 2017-06-05                    2427 Forsyth Rd         6          0
# 2017-09-10     1712 West Spring Creek Parkway         9          1
# 2017-10-01              3950 Las Vegas Blvd S        59        441
# 2017-11-05                         216 4th St        27         20
# 2017-11-14                17357 Stagecoach Rd         6         12
# 2018-02-14                5901 Pine Island Rd        17         17
# 2018-05-18                        16000 Hwy 6        10         13
# 2018-09-12                   660 Manwell Blvd         6          0
